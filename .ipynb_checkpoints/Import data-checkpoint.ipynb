# %%
import pandas as pd
import sqlite3

# %%
from pathlib import Path

# Path.home() automatically finds your Windows User directory (e.g., C:\Users\YourName)
file_path = Path.home() / "Downloads" / "YULA Financial Management - 2025-2026 - BankAccount_mod.csv"


df = pd.read_csv(file_path)
df.head()
# Out:
#          Date Transaction Type Check Number                       Description  \
# 0  09/01/2017           credit          NaN                    Carry  Forward
# 1  09/01/2017           credit          NaN  170901P2 Square Inc 2963 David T
# 2  09/12/2017            debit          NaN  PAYMENT TO CREDIT CARD *********
# 3  09/12/2017           credit          NaN                   COUNTER DEPOSIT
# 4  09/13/2017            debit          NaN               RETURN DEPOSIT ITEM
#
#        Amount Daily Posted Balance Fiscal Year           Category  \
# 0  $11,143.93           $11,143.93      FY2017      carry forward
# 1      $28.83           $11,172.76      FY2018  Merchandise Sales
# 2      -$0.43           $11,172.33      FY2018     Admin/Supplies
# 3     $607.00           $11,779.33      FY2018       Other Income
# 4     -$40.00           $11,739.33      FY2018     Admin/Supplies
#
#                      Notes More Notes  ... Fall.1 Spring.1       Unnamed: 15  \
# 0  Export from NPTreasurer        NaN  ...    NaN      NaN  NEEDS ALLOCAITON
# 1  Export from NPTreasurer        NaN  ...    NaN      NaN  NEEDS ALLOCAITON
# 2  Export from NPTreasurer        NaN  ...    NaN      NaN  NEEDS ALLOCAITON
# 3  Export from NPTreasurer        NaN  ...    NaN      NaN  NEEDS ALLOCAITON
# 4  Export from NPTreasurer        NaN  ...    NaN      NaN  NEEDS ALLOCAITON
#
#   Running Calculated Balance  Delta Fall.2 Winter.1 Spring.2 Fall.3 Spring.3
# 0                 $11,143.93  $0.00    NaN      NaN      NaN    NaN      NaN
# 1                 $11,172.76  $0.00    NaN      NaN      NaN    NaN      NaN
# 2                 $11,172.33  $0.00    NaN      NaN      NaN    NaN      NaN
# 3                 $11,779.33  $0.00    NaN      NaN      NaN    NaN      NaN
# 4                 $11,739.33  $0.00    NaN      NaN      NaN    NaN      NaN
#
# [5 rows x 23 columns]

# %%
conn = sqlite3.connect("data/ledger.db")
# Fetch {name: id} pairs from categories table
cat_map = pd.read_sql("SELECT name, id FROM categories", conn).set_index('name')['id'].to_dict()
cat_map
# Out:
# {'Admin/Supplies': 15,
#  'Better Sports Club': 20,
#  'Bids': 10,
#  'Buses': 11,
#  'Coaches': 12,
#  'Concussion Testing': 21,
#  'Diversity, Equity, Inclusion': 7,
#  'Donation': 1,
#  'Fields': 9,
#  'Fundraising': 2,
#  'Hotels': 13,
#  'Insurance': 14,
#  'Merchandise Purchases': 16,
#  'Merchandise Sales': 6,
#  'Other Expenses': 23,
#  'Other Income': 8,
#  'Outreach': 24,
#  'Registration': 3,
#  'Richmond Rendezvous': 22,
#  'Richmond Rendezvous Bids': 5,
#  'Team Stipends': 17,
#  'Uniforms': 18,
#  'YULA Invite': 19,
#  'YULA Invite Bids': 4}

# %%
cat_map["Concussion"] = 21
cat_map["Richmond Rendevous"] = 22
cat_map["Richmond Rendevous Bids"] = 5
cat_map["carry forward"] = 8
cat_map["Other"] = 23
cat_map["YCC"] = 23
cat_map["Yula Invite"] = 19
cat_map["Yula Invite Bids"] = 4
#cat_map["Outreach"] = 
cat_map
# Out:
# {'Admin/Supplies': 15,
#  'Better Sports Club': 20,
#  'Bids': 10,
#  'Buses': 11,
#  'Coaches': 12,
#  'Concussion Testing': 21,
#  'Diversity, Equity, Inclusion': 7,
#  'Donation': 1,
#  'Fields': 9,
#  'Fundraising': 2,
#  'Hotels': 13,
#  'Insurance': 14,
#  'Merchandise Purchases': 16,
#  'Merchandise Sales': 6,
#  'Other Expenses': 23,
#  'Other Income': 8,
#  'Outreach': 24,
#  'Registration': 3,
#  'Richmond Rendezvous': 22,
#  'Richmond Rendezvous Bids': 5,
#  'Team Stipends': 17,
#  'Uniforms': 18,
#  'YULA Invite': 19,
#  'YULA Invite Bids': 4,
#  'Concussion': 21,
#  'Richmond Rendevous': 22,
#  'Richmond Rendevous Bids': 5,
#  'carry forward': 8,
#  'Other': 23,
#  'YCC': 23,
#  'Yula Invite': 19,
#  'Yula Invite Bids': 4}

# %%
def clean_currency(x):
    if isinstance(x, str):
        x = x.replace('$', '').replace(',', '')
        if '(' in x or '-' in x:
            return -float(x.replace('(', '').replace(')', '').replace('-', ''))
        return float(x)
    return x

df['amount'] = df['Amount'].apply(clean_currency)
df['daily posted balance'] = df['Daily Posted Balance'].apply(clean_currency)
df['running balance'] = df['Running Calculated Balance'].apply(clean_currency)

# %%
# Map CSV 'Category' to category_id
# If not found, it defaults to None (NULL in SQL)
df['category_id'] = df['Category'].map(cat_map)

# %%
df.head()
# Out:
#          Date Transaction Type Check Number                       Description  \
# 0  09/01/2017           credit          NaN                    Carry  Forward
# 1  09/01/2017           credit          NaN  170901P2 Square Inc 2963 David T
# 2  09/12/2017            debit          NaN  PAYMENT TO CREDIT CARD *********
# 3  09/12/2017           credit          NaN                   COUNTER DEPOSIT
# 4  09/13/2017            debit          NaN               RETURN DEPOSIT ITEM
#
#        Amount Daily Posted Balance Fiscal Year           Category  \
# 0  $11,143.93           $11,143.93      FY2017      carry forward
# 1      $28.83           $11,172.76      FY2018  Merchandise Sales
# 2      -$0.43           $11,172.33      FY2018     Admin/Supplies
# 3     $607.00           $11,779.33      FY2018       Other Income
# 4     -$40.00           $11,739.33      FY2018     Admin/Supplies
#
#                      Notes More Notes  ... Running Calculated Balance  Delta  \
# 0  Export from NPTreasurer        NaN  ...                 $11,143.93  $0.00
# 1  Export from NPTreasurer        NaN  ...                 $11,172.76  $0.00
# 2  Export from NPTreasurer        NaN  ...                 $11,172.33  $0.00
# 3  Export from NPTreasurer        NaN  ...                 $11,779.33  $0.00
# 4  Export from NPTreasurer        NaN  ...                 $11,739.33  $0.00
#
#   Fall.2 Winter.1 Spring.2 Fall.3 Spring.3    amount daily posted balance  \
# 0    NaN      NaN      NaN    NaN      NaN  11143.93             11143.93
# 1    NaN      NaN      NaN    NaN      NaN     28.83             11172.76
# 2    NaN      NaN      NaN    NaN      NaN     -0.43             11172.33
# 3    NaN      NaN      NaN    NaN      NaN    607.00             11779.33
# 4    NaN      NaN      NaN    NaN      NaN    -40.00             11739.33
#
#   category_id
# 0         8.0
# 1         6.0
# 2        15.0
# 3         8.0
# 4        15.0
#
# [5 rows x 26 columns]

# %%
# Group by columns and count rows in each group
#cat_column = df.groupby(['Category', 'category_id']).size().reset_index(name='count')
# Set dropna=False to include rows where column_b (or column_a) is null
cat_column = df.groupby(['Category', 'category_id'], dropna=False).size().reset_index(name='count')

cat_column
# Out:
#                         Category  category_id  count
# 0                                         NaN      1
# 1                 Admin/Supplies         15.0    165
# 2             Better Sports Club         20.0      7
# 3                           Bids         10.0     93
# 4                          Buses         11.0     24
# 5                        Coaches         12.0    354
# 6                     Concussion         21.0      5
# 7   Diversity, Equity, Inclusion          7.0      2
# 8                       Donation          1.0     44
# 9                         Fields          9.0     33
# 10                   Fundraising          2.0     22
# 11                        Hotels         13.0     28
# 12                     Insurance         14.0     12
# 13         Merchandise Purchases         16.0     20
# 14             Merchandise Sales          6.0     82
# 15                         Other         23.0     59
# 16                  Other Income          8.0     11
# 17                      Outreach         24.0     17
# 18                  Registration          3.0   1105
# 19            Richmond Rendevous         22.0      5
# 20       Richmond Rendevous Bids          5.0      5
# 21                 Team Stipends         17.0    184
# 22                      Uniforms         18.0     33
# 23                           YCC         23.0     14
# 24                   YULA Invite         19.0    104
# 25              YULA Invite Bids          4.0    184
# 26                   Yula Invite         19.0     20
# 27              Yula Invite Bids          4.0      4
# 28                 carry forward          8.0      1
# 29                           NaN          NaN      7

# %%
cat_id = df[['Category', 'category_id']].value_counts(dropna=False).reset_index(name='count')
cat_id
# Out:
#                         Category  category_id  count
# 0                   Registration          3.0   1105
# 1                        Coaches         12.0    354
# 2                  Team Stipends         17.0    184
# 3               YULA Invite Bids          4.0    184
# 4                 Admin/Supplies         15.0    165
# 5                    YULA Invite         19.0    104
# 6                           Bids         10.0     93
# 7              Merchandise Sales          6.0     82
# 8                          Other          NaN     59
# 9                       Donation          1.0     44
# 10                      Uniforms         18.0     33
# 11                        Fields          9.0     33
# 12                        Hotels         13.0     28
# 13                         Buses         11.0     24
# 14                   Fundraising          2.0     22
# 15         Merchandise Purchases         16.0     20
# 16                   Yula Invite          NaN     20
# 17                      Outreach          NaN     17
# 18                           YCC          NaN     14
# 19                     Insurance         14.0     12
# 20                  Other Income          8.0     11
# 21                           NaN          NaN      7
# 22            Better Sports Club         20.0      7
# 23       Richmond Rendevous Bids          NaN      5
# 24            Richmond Rendevous          NaN      5
# 25                    Concussion          NaN      5
# 26              Yula Invite Bids          NaN      4
# 27  Diversity, Equity, Inclusion          7.0      2
# 28                 carry forward          NaN      1
# 29                                        NaN      1

# %%
# Group by columns and count rows in each group
cat_id = df.groupby(['category_id']).size().reset_index(name='count')
cat_id
# Out:
#     category_id  count
# 0           1.0     44
# 1           2.0     22
# 2           3.0   1105
# 3           4.0    188
# 4           5.0      5
# 5           6.0     82
# 6           7.0      2
# 7           8.0     12
# 8           9.0     33
# 9          10.0     93
# 10         11.0     24
# 11         12.0    354
# 12         13.0     28
# 13         14.0     12
# 14         15.0    165
# 15         16.0     20
# 16         17.0    184
# 17         18.0     33
# 18         19.0    124
# 19         20.0      7
# 20         21.0      5
# 21         22.0      5
# 22         23.0     73
# 23         24.0     17

# %%
# 4. Prepare for Ledger
    ledger_df = pd.DataFrame({
        'transaction_date': df['Date'],
        'description': df['Description'],
        'amount': df['amount'],
        'transaction_type': df['Transaction Type'],
        'check_number': df['Check Number'],
        'daily_posted_balance': df['daily posted balance'],
        'running_balance': df['running balance'],
        'category_id': df['category_id'],
        'fiscal_year_id': df['category_id'],
        'source_indicator': 'Import',
        'is_deleted': 0
        # Add other fields here as needed
    })
